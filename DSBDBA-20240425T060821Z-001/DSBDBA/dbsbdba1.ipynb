# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 102)

# %%
df=pd.read_csv("NFL.csv")
# Out:
# <ipython-input-6-ae5214a11b69>:1: DtypeWarning: Columns (51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("NFL.csv")

# %% [markdown]
# Print data set

# %%
df
# Out:
#              Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0      2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1      2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2      2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3      2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4      2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
# ...           ...         ...    ...  ...   ...    ...        ...       ...
# 10905  2009-10-11  2009101107     16    4   3.0  13:21         14     801.0
# 10906  2009-10-11  2009101107     16    4   1.0  12:39         13     759.0
# 10907  2009-10-11  2009101107     16    4   2.0  12:05         13     725.0
# 10908  2009-10-11  2009101107     16    4   1.0  11:28         12     688.0
# 10909  2009-10-11  2009101107     16    4   2.0  11:22         12     682.0
#
# ...

# %% [markdown]
# List of columns in Dataset

# %%
columns_list=df.columns
print(columns_list)
# Out:
# Index(['Date', 'GameID', 'Drive', 'qtr', 'down', 'time', 'TimeUnder',
#        'TimeSecs', 'PlayTimeDiff', 'SideofField',
#        ...
#        'yacEPA', 'Home_WP_pre', 'Away_WP_pre', 'Home_WP_post', 'Away_WP_post',
#        'Win_Prob', 'WPA', 'airWPA', 'yacWPA', 'Season'],
#       dtype='object', length=102)

# %% [markdown]
# Data Set description

# %%
df.describe()
# Out:
#              GameID         Drive           qtr         down     TimeUnder  \
# count  1.091000e+04  10910.000000  10910.000000  9240.000000  10910.000000
# mean   2.009094e+09     12.045646      2.560953     2.013745      7.334280
# std    3.626411e+03      7.057477      1.125907     1.011636      4.644043
# min    2.009091e+09      1.000000      1.000000     1.000000      0.000000
# 25%    2.009091e+09      6.000000      2.000000     1.000000      3.000000
# 50%    2.009092e+09     12.000000      2.000000     2.000000      7.000000
# 75%    2.009093e+09     18.000000      4.000000     3.000000     11.000000
# max    2.009101e+09     32.000000      5.000000     4.000000     15.000000
#
#            TimeSecs  PlayTimeDiff         yrdln    yrdline100       ydstogo  \
# count  10900.000000  10890.000000  10885.000000  10885.000000  10910.000000
# mean    1708.094954     20.976217     28.257418     47.797520      7.303391
# ...

# %%
df_shape=df.shape

# %% [markdown]
# Columns data types

# %%
columns_dtypes=df.dtypes

# %% [markdown]
# Count of null values in column

# %%
isnull_count=df.isnull().sum()[df.isnull().sum() != 0]
isnull_count_total=df.isnull().sum()
print("*"*50)
print(isnull_count)
print("*"*50)
print(isnull_count_total)
# Out:
# **************************************************
# down                    1670
# time                      10
# TimeSecs                  10
# PlayTimeDiff              20
# SideofField               19
# yrdln                     25
# yrdline100                25
# GoalToGo                  25
# FirstDown                772
# posteam                  728
# DefensiveTeam            728
# ExPointResult          10648
# TwoPointConv           10896
# DefTwoPoint            10910
# PuntResult             10304
# Passer                  6500
# PassOutcome             6499
# PassLength              6524
# PassLocation            6524
# Interceptor            10794
# Rusher                  7611
# RunLocation             7640
# RunGap                  8536
# Receiver                6651
# ReturnResult           10579
# Returner               10122
# BlockingPlayer         10908
# Tackler1                4306
# Tackler2                9401
# FieldGoalResult        10682
# ...

# %% [markdown]
# Number of duplicate entries in dataset

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Dataframe filled with 0 where null

# %%
df_zero_filledna=df.fillna(0)
df_zero_filledna

# %% [markdown]
# Normalizing TimeSecs column

# %%
df["TimeSecs"].dtype
df["TimeSecs"].isnull().sum()
# Out:
# 144

# %%
tempdf=df.loc[df['TimeSecs'] > 0]
print(type(tempdf))
tempdf['TimeSecs'].isnull().sum()
# df['TimeSecs'].isnull().sum()
# tempdf.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 0

# %%
from sklearn.preprocessing import minmax_scale

# %%
tempdf = minmax_scale(tempdf["TimeSecs"])
print(tempdf)
# Out:
# [1.         0.99805502 0.98777438 ... 0.19283134 0.19171992 0.17921645]

# %%
#df["TimeSecs"] = pd.to_numeric(df["TimeSecs"])
df["TimeSecs"].fillna(df["TimeSecs"].mean(),inplace=True)

# %%
df.isnull().sum()[df.isnull().sum() != 0]

# %%
trial_df=df.copy()
for i in columns_list:
    if columns_dtypes[i]!=["int64","float64"]:
        print(i)
#         df[i].fillna(df[i].mode(),inplace=True)
# df.isnull().sum()[df.isnull().sum() != 0]

# %%
trial_columns_list=trial_df.columns.tolist()
trial_columns_dtypes=trial_df.dtypes
for i in trial_columns_list:
    if trial_columns_dtypes[i]!=["int64","float64"]:
        print(i)
